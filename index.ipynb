# %% [markdown]
# # Lambda Functions - Lab
#
# ## Introduction
#
# In this lab, you'll get some hands-on practice creating and using lambda functions.
#
# ## Objectives
#
# In this lab you will:
#
# * Create lambda functions to use as arguments of other functions
# * Use the `.map()` or `.apply()` method to apply a function to a pandas series or DataFrame

# %% [markdown]
# ## Lambda Functions

# %%
import pandas as pd
df = pd.read_csv('Yelp_Reviews.csv', index_col=0)
df.head(2)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2610 entries, 1 to 4206
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   business_id  2610 non-null   object
#  1   cool         2610 non-null   int64
#  2   date         2610 non-null   object
#  3   funny        2610 non-null   int64
#  4   review_id    2610 non-null   object
#  5   stars        2610 non-null   int64
#  6   text         2610 non-null   object
#  7   useful       2610 non-null   int64
#  8   user_id      2610 non-null   object
# dtypes: int64(4), object(5)
# memory usage: 203.9+ KB

# %% [markdown]
# ## Simple arithmetic
#
# Use a lambda function to create a new column called `'stars_squared'` by squaring the stars column.

# %%
# Your code here
df['stars_squared'] = df['stars'].map(lambda x: x**2)
df
# Out:
#                  business_id  cool        date  funny               review_id  \
# 1     pomGBqfbxcqPv14c3XH-ZQ     0  2012-11-13      0  dDl8zu1vWPdKGihJrwQbpw
# 2     jtQARsP6P-LbkyjbO1qNGg     1  2014-10-23      1  LZp4UX5zK3e-c5ZGSeo3kA
# 4     Ums3gaP2qM3W1XcA5r6SsQ     0  2014-09-05      0  jsDu6QEJHbwP2Blom1PLCA
# 5     vgfcTvK81oD4r50NMjU2Ag     0  2011-02-25      0  pfavA0hr3nyqO61oupj-lA
# 10    yFumR3CWzpfvTH2FCthvVw     0  2016-06-15      0  STiFMww2z31siPY7BWNC2g
# ...                      ...   ...         ...    ...                     ...
# 689   BTcY04QFiS1uh-RpkR7rAg     1  2013-06-02      0  6_A58CCY8SHB7r-Wu7-A5g
# 4874  t0T_4MM4EUHbCzBTF11FHA     0  2016-08-14      0  KqQwNyfoFiJOw911mrULIg
# 564   5XYR6doRa5Nj1JMfSDei6A     1  2016-06-14      0  xlGJkxoIBl8XH8wVsPZpnw
# 3458  aLcFhMe6DDJ430zelCpd2A     0  2013-10-02      0  kwiEG_KCpDB6aK5fTSM7iw
# 4206  WdBWhGe4Siqg3IYTc4_K4A     0  2016-08-15      0  O0ttxNGxHKtD8Cnnwc_j1g
#
#       stars                                               text  useful  \
# 1         5  I love this place! My fiance And I go here atl...       0
# 2         1  Terrible. Dry corn bread. Rib tips were all fa...       3
# 4         5  Delicious healthy food. The steak is amazing. ...       0
# 5         1  This place sucks. The customer service is horr...       2
# 10        5  I have been an Emerald Club member for a numbe...       0
# ...     ...                                                ...     ...
# 689       5  Came here with my 2 year old daughter for our ...       2
# 4874      5  Great little restaurant. Not to many tables an...       0
# 564       5  Always great friendly service and fresh baked ...       0
# 3458      2  We were expecting amazing Thai food after all ...       1
# 4206      1  Sunday at 8p. Not many people here at all. We ...       0
#
#                      user_id  stars_squared
# 1     msQe1u7Z_XuqjGoqhB0J5g             25
# 2     msQe1u7Z_XuqjGoqhB0J5g              1
# 4     msQe1u7Z_XuqjGoqhB0J5g             25
# 5     msQe1u7Z_XuqjGoqhB0J5g              1
# 10    TlvV-xJhmh7LCwJYXkV-cg             25
# ...                      ...            ...
# 689   q3AiAe-AcpDrNsdZf8nCvQ             25
# 4874  NJxaA7q9BhqaDrFpfR2Jeg             25
# 564   kBNFdviedCPFWyR-wVaAzw             25
# 3458  PkRFSQgSfca9Tamq7b2LdQ              4
# 4206  ic9zIsm7zoxUm3Axyegx8g              1
#
# [2610 rows x 10 columns]

# %% [markdown]
# ## Dates
# Select the month from the date string using a lambda function.

# %%
# Your code here
df['month'] = df['date'].apply(lambda x: x[5:7])
df
# Out:
#                  business_id  cool        date  funny               review_id  \
# 1     pomGBqfbxcqPv14c3XH-ZQ     0  2012-11-13      0  dDl8zu1vWPdKGihJrwQbpw
# 2     jtQARsP6P-LbkyjbO1qNGg     1  2014-10-23      1  LZp4UX5zK3e-c5ZGSeo3kA
# 4     Ums3gaP2qM3W1XcA5r6SsQ     0  2014-09-05      0  jsDu6QEJHbwP2Blom1PLCA
# 5     vgfcTvK81oD4r50NMjU2Ag     0  2011-02-25      0  pfavA0hr3nyqO61oupj-lA
# 10    yFumR3CWzpfvTH2FCthvVw     0  2016-06-15      0  STiFMww2z31siPY7BWNC2g
# ...                      ...   ...         ...    ...                     ...
# 689   BTcY04QFiS1uh-RpkR7rAg     1  2013-06-02      0  6_A58CCY8SHB7r-Wu7-A5g
# 4874  t0T_4MM4EUHbCzBTF11FHA     0  2016-08-14      0  KqQwNyfoFiJOw911mrULIg
# 564   5XYR6doRa5Nj1JMfSDei6A     1  2016-06-14      0  xlGJkxoIBl8XH8wVsPZpnw
# 3458  aLcFhMe6DDJ430zelCpd2A     0  2013-10-02      0  kwiEG_KCpDB6aK5fTSM7iw
# 4206  WdBWhGe4Siqg3IYTc4_K4A     0  2016-08-15      0  O0ttxNGxHKtD8Cnnwc_j1g
#
#       stars                                               text  useful  \
# 1         5  I love this place! My fiance And I go here atl...       0
# 2         1  Terrible. Dry corn bread. Rib tips were all fa...       3
# 4         5  Delicious healthy food. The steak is amazing. ...       0
# 5         1  This place sucks. The customer service is horr...       2
# 10        5  I have been an Emerald Club member for a numbe...       0
# ...     ...                                                ...     ...
# 689       5  Came here with my 2 year old daughter for our ...       2
# 4874      5  Great little restaurant. Not to many tables an...       0
# 564       5  Always great friendly service and fresh baked ...       0
# 3458      2  We were expecting amazing Thai food after all ...       1
# 4206      1  Sunday at 8p. Not many people here at all. We ...       0
#
#                      user_id month
# 1     msQe1u7Z_XuqjGoqhB0J5g    11
# 2     msQe1u7Z_XuqjGoqhB0J5g    10
# 4     msQe1u7Z_XuqjGoqhB0J5g    09
# 5     msQe1u7Z_XuqjGoqhB0J5g    02
# 10    TlvV-xJhmh7LCwJYXkV-cg    06
# ...                      ...   ...
# 689   q3AiAe-AcpDrNsdZf8nCvQ    06
# 4874  NJxaA7q9BhqaDrFpfR2Jeg    08
# 564   kBNFdviedCPFWyR-wVaAzw    06
# 3458  PkRFSQgSfca9Tamq7b2LdQ    10
# 4206  ic9zIsm7zoxUm3Axyegx8g    08
#
# [2610 rows x 10 columns]

# %% [markdown]
# ## What is the average number of words for a yelp review?
# Do this with a single line of code!

# %%
# Your code here
df['num_words'] = df['text'].apply(lambda x: len(x.split()))
df
# Out:
#                  business_id  cool        date  funny               review_id  \
# 1     pomGBqfbxcqPv14c3XH-ZQ     0  2012-11-13      0  dDl8zu1vWPdKGihJrwQbpw
# 2     jtQARsP6P-LbkyjbO1qNGg     1  2014-10-23      1  LZp4UX5zK3e-c5ZGSeo3kA
# 4     Ums3gaP2qM3W1XcA5r6SsQ     0  2014-09-05      0  jsDu6QEJHbwP2Blom1PLCA
# 5     vgfcTvK81oD4r50NMjU2Ag     0  2011-02-25      0  pfavA0hr3nyqO61oupj-lA
# 10    yFumR3CWzpfvTH2FCthvVw     0  2016-06-15      0  STiFMww2z31siPY7BWNC2g
# ...                      ...   ...         ...    ...                     ...
# 689   BTcY04QFiS1uh-RpkR7rAg     1  2013-06-02      0  6_A58CCY8SHB7r-Wu7-A5g
# 4874  t0T_4MM4EUHbCzBTF11FHA     0  2016-08-14      0  KqQwNyfoFiJOw911mrULIg
# 564   5XYR6doRa5Nj1JMfSDei6A     1  2016-06-14      0  xlGJkxoIBl8XH8wVsPZpnw
# 3458  aLcFhMe6DDJ430zelCpd2A     0  2013-10-02      0  kwiEG_KCpDB6aK5fTSM7iw
# 4206  WdBWhGe4Siqg3IYTc4_K4A     0  2016-08-15      0  O0ttxNGxHKtD8Cnnwc_j1g
#
#       stars                                               text  useful  \
# 1         5  I love this place! My fiance And I go here atl...       0
# 2         1  Terrible. Dry corn bread. Rib tips were all fa...       3
# 4         5  Delicious healthy food. The steak is amazing. ...       0
# 5         1  This place sucks. The customer service is horr...       2
# 10        5  I have been an Emerald Club member for a numbe...       0
# ...     ...                                                ...     ...
# 689       5  Came here with my 2 year old daughter for our ...       2
# 4874      5  Great little restaurant. Not to many tables an...       0
# 564       5  Always great friendly service and fresh baked ...       0
# 3458      2  We were expecting amazing Thai food after all ...       1
# 4206      1  Sunday at 8p. Not many people here at all. We ...       0
#
#                      user_id month  num_words
# 1     msQe1u7Z_XuqjGoqhB0J5g    11         58
# 2     msQe1u7Z_XuqjGoqhB0J5g    10         30
# 4     msQe1u7Z_XuqjGoqhB0J5g    09         30
# 5     msQe1u7Z_XuqjGoqhB0J5g    02         82
# 10    TlvV-xJhmh7LCwJYXkV-cg    06         32
# ...                      ...   ...        ...
# 689   q3AiAe-AcpDrNsdZf8nCvQ    06         61
# 4874  NJxaA7q9BhqaDrFpfR2Jeg    08         43
# 564   kBNFdviedCPFWyR-wVaAzw    06         79
# 3458  PkRFSQgSfca9Tamq7b2LdQ    10        185
# 4206  ic9zIsm7zoxUm3Axyegx8g    08         42
#
# [2610 rows x 11 columns]

# %% [markdown]
# ## Create a new column for the number of words in the review

# %%
# Your code here

# %% [markdown]
# ## Rewrite the following as a lambda function
#
# Create a new column `'Review_Length'` by applying this lambda function to the `'Review_num_words'` column.

# %%
# Rewrite the following function as a lambda function
def rewrite_as_lambda(value):
    if len(value) < 50:
        return 'Short'
    elif len(value) < 80:
        return 'Medium'
    else:
        return 'Long'
# Hint: nest your if, else conditionals

df['Review_length'] = df['num_words'].apply(lambda x: 'Short' if x < 50 else ('Medium' if x<80 else 'Long'))

# %%
df
# Out:
#                  business_id  cool        date  funny               review_id  \
# 1     pomGBqfbxcqPv14c3XH-ZQ     0  2012-11-13      0  dDl8zu1vWPdKGihJrwQbpw
# 2     jtQARsP6P-LbkyjbO1qNGg     1  2014-10-23      1  LZp4UX5zK3e-c5ZGSeo3kA
# 4     Ums3gaP2qM3W1XcA5r6SsQ     0  2014-09-05      0  jsDu6QEJHbwP2Blom1PLCA
# 5     vgfcTvK81oD4r50NMjU2Ag     0  2011-02-25      0  pfavA0hr3nyqO61oupj-lA
# 10    yFumR3CWzpfvTH2FCthvVw     0  2016-06-15      0  STiFMww2z31siPY7BWNC2g
# ...                      ...   ...         ...    ...                     ...
# 689   BTcY04QFiS1uh-RpkR7rAg     1  2013-06-02      0  6_A58CCY8SHB7r-Wu7-A5g
# 4874  t0T_4MM4EUHbCzBTF11FHA     0  2016-08-14      0  KqQwNyfoFiJOw911mrULIg
# 564   5XYR6doRa5Nj1JMfSDei6A     1  2016-06-14      0  xlGJkxoIBl8XH8wVsPZpnw
# 3458  aLcFhMe6DDJ430zelCpd2A     0  2013-10-02      0  kwiEG_KCpDB6aK5fTSM7iw
# 4206  WdBWhGe4Siqg3IYTc4_K4A     0  2016-08-15      0  O0ttxNGxHKtD8Cnnwc_j1g
#
#       stars                                               text  useful  \
# 1         5  I love this place! My fiance And I go here atl...       0
# 2         1  Terrible. Dry corn bread. Rib tips were all fa...       3
# 4         5  Delicious healthy food. The steak is amazing. ...       0
# 5         1  This place sucks. The customer service is horr...       2
# 10        5  I have been an Emerald Club member for a numbe...       0
# ...     ...                                                ...     ...
# 689       5  Came here with my 2 year old daughter for our ...       2
# 4874      5  Great little restaurant. Not to many tables an...       0
# 564       5  Always great friendly service and fresh baked ...       0
# 3458      2  We were expecting amazing Thai food after all ...       1
# 4206      1  Sunday at 8p. Not many people here at all. We ...       0
#
#                      user_id month  num_words Review_length
# 1     msQe1u7Z_XuqjGoqhB0J5g    11         58        Medium
# 2     msQe1u7Z_XuqjGoqhB0J5g    10         30         Short
# 4     msQe1u7Z_XuqjGoqhB0J5g    09         30         Short
# 5     msQe1u7Z_XuqjGoqhB0J5g    02         82          Long
# 10    TlvV-xJhmh7LCwJYXkV-cg    06         32         Short
# ...                      ...   ...        ...           ...
# 689   q3AiAe-AcpDrNsdZf8nCvQ    06         61        Medium
# 4874  NJxaA7q9BhqaDrFpfR2Jeg    08         43         Short
# 564   kBNFdviedCPFWyR-wVaAzw    06         79        Medium
# 3458  PkRFSQgSfca9Tamq7b2LdQ    10        185          Long
# 4206  ic9zIsm7zoxUm3Axyegx8g    08         42         Short
#
# [2610 rows x 12 columns]

# %% [markdown]
# ## Level Up: Dates Advanced!
# <img src="images/world_map.png" width="600">
#
# Print the first five rows of the `'date'` column.

# %%
# Your code here
df.date.head()
# Out:
# 1     2012-11-13
# 2     2014-10-23
# 4     2014-09-05
# 5     2011-02-25
# 10    2016-06-15
# Name: date, dtype: object

# %% [markdown]
# Overwrite the `'date'` column by reordering the month and day from `YYYY-MM-DD` to `DD-MM-YYYY`. Try to do this using a lambda function.

# %%
# Your code here
df['new_date'] = df['date'].apply(lambda x: x[-2:] + x[4:8] + x[0:4])
df['date'] = df['new_date']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\kapta\Documents\Flatiron\Module 1\dsc-lambda-functions-lab\index.ipynb Cell 18 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/kapta/Documents/Flatiron/Module%201/dsc-lambda-functions-lab/index.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> df['new_date'] = df['date'].apply(lambda x: x[-2:] + x[4:8] + x[0:4])
#       <a href='vscode-notebook-cell:/c%3A/Users/kapta/Documents/Flatiron/Module%201/dsc-lambda-functions-lab/index.ipynb#X22sZmlsZQ%3D%3D?line=2'>3</a> df['date'] = df['new_date']
# ----> <a href='vscode-notebook-cell:/c%3A/Users/kapta/Documents/Flatiron/Module%201/dsc-lambda-functions-lab/index.ipynb#X22sZmlsZQ%3D%3D?line=3'>4</a> df['new_date'].drop()
#       <a href='vscode-notebook-cell:/c%3A/Users/kapta/Documents/Flatiron/Module%201/dsc-lambda-functions-lab/index.ipynb#X22sZmlsZQ%3D%3D?line=4'>5</a> df
#
# File c:\Users\kapta\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\kapta\anaconda3\lib\site-packages\pandas\core\series.py:4771, in Series.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4674 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4675 def drop(
#    4676     self,
#    (...)
#    4683     errors="raise",
#    4684 ) -> Series:
#    4685     """
#    4686     Return Series with specified index labels removed.
#    4687
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return super().drop(
#    4772         labels=labels,
#    4773         axis=axis,
#    4774         index=index,
#    4775         columns=columns,
#    4776         level=level,
#    4777         inplace=inplace,
#    4778         errors=errors,
#    4779     )
#
# File c:\Users\kapta\anaconda3\lib\site-packages\pandas\core\generic.py:4259, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4257     axes, _ = self._construct_axes_from_arguments((index, columns), {})
#    4258 else:
# -> 4259     raise ValueError(
#    4260         "Need to specify at least one of 'labels', 'index' or 'columns'"
#    4261     )
#    4263 obj = self
#    4265 for axis, labels in axes.items():
#
# ValueError: Need to specify at least one of 'labels', 'index' or 'columns'

# %%
df.drop(columns=['new_date'],inplace=True)
df
# Out:
#                  business_id  cool        date  funny               review_id  \
# 1     pomGBqfbxcqPv14c3XH-ZQ     0  13-11-2012      0  dDl8zu1vWPdKGihJrwQbpw
# 2     jtQARsP6P-LbkyjbO1qNGg     1  23-10-2014      1  LZp4UX5zK3e-c5ZGSeo3kA
# 4     Ums3gaP2qM3W1XcA5r6SsQ     0  05-09-2014      0  jsDu6QEJHbwP2Blom1PLCA
# 5     vgfcTvK81oD4r50NMjU2Ag     0  25-02-2011      0  pfavA0hr3nyqO61oupj-lA
# 10    yFumR3CWzpfvTH2FCthvVw     0  15-06-2016      0  STiFMww2z31siPY7BWNC2g
# ...                      ...   ...         ...    ...                     ...
# 689   BTcY04QFiS1uh-RpkR7rAg     1  02-06-2013      0  6_A58CCY8SHB7r-Wu7-A5g
# 4874  t0T_4MM4EUHbCzBTF11FHA     0  14-08-2016      0  KqQwNyfoFiJOw911mrULIg
# 564   5XYR6doRa5Nj1JMfSDei6A     1  14-06-2016      0  xlGJkxoIBl8XH8wVsPZpnw
# 3458  aLcFhMe6DDJ430zelCpd2A     0  02-10-2013      0  kwiEG_KCpDB6aK5fTSM7iw
# 4206  WdBWhGe4Siqg3IYTc4_K4A     0  15-08-2016      0  O0ttxNGxHKtD8Cnnwc_j1g
#
#       stars                                               text  useful  \
# 1         5  I love this place! My fiance And I go here atl...       0
# 2         1  Terrible. Dry corn bread. Rib tips were all fa...       3
# 4         5  Delicious healthy food. The steak is amazing. ...       0
# 5         1  This place sucks. The customer service is horr...       2
# 10        5  I have been an Emerald Club member for a numbe...       0
# ...     ...                                                ...     ...
# 689       5  Came here with my 2 year old daughter for our ...       2
# 4874      5  Great little restaurant. Not to many tables an...       0
# 564       5  Always great friendly service and fresh baked ...       0
# 3458      2  We were expecting amazing Thai food after all ...       1
# 4206      1  Sunday at 8p. Not many people here at all. We ...       0
#
#                      user_id month  num_words Review_length
# 1     msQe1u7Z_XuqjGoqhB0J5g    11         58        Medium
# 2     msQe1u7Z_XuqjGoqhB0J5g    10         30         Short
# 4     msQe1u7Z_XuqjGoqhB0J5g    09         30         Short
# 5     msQe1u7Z_XuqjGoqhB0J5g    02         82          Long
# 10    TlvV-xJhmh7LCwJYXkV-cg    06         32         Short
# ...                      ...   ...        ...           ...
# 689   q3AiAe-AcpDrNsdZf8nCvQ    06         61        Medium
# 4874  NJxaA7q9BhqaDrFpfR2Jeg    08         43         Short
# 564   kBNFdviedCPFWyR-wVaAzw    06         79        Medium
# 3458  PkRFSQgSfca9Tamq7b2LdQ    10        185          Long
# 4206  ic9zIsm7zoxUm3Axyegx8g    08         42         Short
#
# [2610 rows x 12 columns]

# %% [markdown]
# ## Summary
#
# Great! Hopefully, you're getting the hang of lambda functions now! It's important not to overuse them - it will often make more sense to define a function so that it's reusable elsewhere. But whenever you need to quickly apply some simple processing to a collection of data you have a new technique that will help you to do just that. It'll also be useful if you're reading someone else's code that happens to use lambdas.
